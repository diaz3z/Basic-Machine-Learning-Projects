# %%
import pandas as pd

# %%
url = "train_luc.csv"
df = pd.read_csv(url)

# %%
df.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9174 entries, 0 to 9173
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    9174 non-null   object
#  1   season      9174 non-null   int64
#  2   holiday     9174 non-null   int64
#  3   workingday  9174 non-null   int64
#  4   weather     9174 non-null   int64
#  5   temp        9174 non-null   float64
#  6   atemp       9174 non-null   float64
#  7   humidity    9174 non-null   int64
#  8   windspeed   9174 non-null   float64
#  9   casual      9174 non-null   int64
#  10  registered  9174 non-null   int64
#  11  count       9174 non-null   int64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 860.2+ KB

# %%
df.shape
# Out:
# (9174, 12)

# %%
df.isnull().sum()
# Out:
# datetime      0
# season        0
# holiday       0
# workingday    0
# weather       0
# temp          0
# atemp         0
# humidity      0
# windspeed     0
# casual        0
# registered    0
# count         0
# dtype: int64

# %%
print(df.describe())
# Out:
#             season      holiday   workingday      weather         temp  \
# count  9174.000000  9174.000000  9174.000000  9174.000000  9174.000000
# mean      2.505559     0.031284     0.678875     1.414868    20.130401
# std       1.116618     0.174094     0.466934     0.635363     7.940504
# min       1.000000     0.000000     0.000000     1.000000     0.820000
# 25%       2.000000     0.000000     0.000000     1.000000    13.940000
# 50%       3.000000     0.000000     1.000000     1.000000    20.500000
# 75%       4.000000     0.000000     1.000000     2.000000    27.060000
# max       4.000000     1.000000     1.000000     4.000000    41.000000
#
#              atemp     humidity    windspeed       casual   registered  \
# count  9174.000000  9174.000000  9174.000000  9174.000000  9174.000000
# mean     23.578433    61.715064    12.737931    35.713647   154.868106
# std       8.617957    19.401829     8.199027    49.667738   150.981155
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize= (8,6))
plt.hist(df['count'], bins=20, color='skyblue', edgecolor= 'black')
plt.title('distribution of count')
plt.xlabel('Count')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)
plt.show()

# %%
plt.figure(figsize= (8,5))
plt.scatter(df['temp'], df['count'], alpha=0.5, color='skyblue')
plt.title('Temperature vs Count')
plt.xlabel('Temperature')
plt.ylabel('Count')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize= (8,5))
sns.boxplot(x='season', y='count', data=df, palette='Set2')
plt.title('Season vs Count')
plt.xlabel('Season')
plt.ylabel('Count')
plt.grid(True)
plt.show()
# Out:
# C:\Users\mdzai\AppData\Local\Temp\ipykernel_18428\900212986.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='season', y='count', data=df, palette='Set2')

# %%
plt.figure(figsize= (8,5))
sns.barplot(x='holiday', y='count', data=df, palette='Set3')
plt.title('Holiday vs Count')
plt.xlabel('Holiday')
plt.ylabel('Count')
plt.grid(True)
plt.show()
# Out:
# C:\Users\mdzai\AppData\Local\Temp\ipykernel_18428\902252645.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='holiday', y='count', data=df, palette='Set3')

# %%
df['datetime'] = pd.to_datetime(df['datetime'])

plt.figure(figsize= (8,5))
plt.plot(df['datetime'], df['count'], marker='o', linestyle='-', color='green')
plt.title('Datetime vs Count')
plt.xlabel('Datetime')
plt.ylabel('Count')
plt.grid(True)
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize= (8,5))
sns.barplot(x='workingday', y='count', data=df, palette='Set1')
plt.title('Workingday vs Count')
plt.xlabel('workingday')
plt.ylabel('Count')
plt.grid(True)
plt.show()
# Out:
# C:\Users\mdzai\AppData\Local\Temp\ipykernel_18428\2555178559.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='workingday', y='count', data=df, palette='Set1')

# %%
df['hour'] = df['datetime'].dt.hour
df['day'] = df['datetime'].dt.day
df['month'] = df['datetime'].dt.month
df['year'] = df['datetime'].dt.year
print(df.head())
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count  hour  day  month  year
# 0        81        0.0       3          13     16     0    1      1  2011
# 1        80        0.0       8          32     40     1    1      1  2011
# 2        80        0.0       5          27     32     2    1      1  2011
# 3        75        0.0       3          10     13     3    1      1  2011
# 4        75        0.0       0           1      1     4    1      1  2011

# %%
df_encoded = pd.get_dummies(df, columns = ['season', 'holiday', 'workingday', 'weather'], drop_first=True)
print(df_encoded.head())
# Out:
#              datetime  temp   atemp  humidity  windspeed  casual  registered  \
# 0 2011-01-01 00:00:00  9.84  14.395        81        0.0       3          13
# 1 2011-01-01 01:00:00  9.02  13.635        80        0.0       8          32
# 2 2011-01-01 02:00:00  9.02  13.635        80        0.0       5          27
# 3 2011-01-01 03:00:00  9.84  14.395        75        0.0       3          10
# 4 2011-01-01 04:00:00  9.84  14.395        75        0.0       0           1
#
#    count  hour  day  month  year  season_2  season_3  season_4  holiday_1  \
# 0     16     0    1      1  2011     False     False     False      False
# 1     40     1    1      1  2011     False     False     False      False
# 2     32     2    1      1  2011     False     False     False      False
# 3     13     3    1      1  2011     False     False     False      False
# 4      1     4    1      1  2011     False     False     False      False
#
#    workingday_1  weather_2  weather_3  weather_4
# ...

# %%
columns_drop = ['datetime', 'casual', 'registered']
df_encoded = df_encoded.drop(columns=columns_drop)
print(df_encoded.head())
# Out:
#    temp   atemp  humidity  windspeed  count  hour  day  month  year  season_2  \
# 0  9.84  14.395        81        0.0     16     0    1      1  2011     False
# 1  9.02  13.635        80        0.0     40     1    1      1  2011     False
# 2  9.02  13.635        80        0.0     32     2    1      1  2011     False
# 3  9.84  14.395        75        0.0     13     3    1      1  2011     False
# 4  9.84  14.395        75        0.0      1     4    1      1  2011     False
#
#    season_3  season_4  holiday_1  workingday_1  weather_2  weather_3  \
# 0     False     False      False         False      False      False
# 1     False     False      False         False      False      False
# 2     False     False      False         False      False      False
# 3     False     False      False         False      False      False
# 4     False     False      False         False      False      False
#
#    weather_4
# 0      False
# 1      False
# 2      False
# 3      False
# ...

# %%
import numpy as np
df_encoded['transform_count'] = np.log1p(df_encoded['count'])
print(df_encoded.head())
# Out:
#    temp   atemp  humidity  windspeed  count  hour  day  month  year  season_2  \
# 0  9.84  14.395        81        0.0     16     0    1      1  2011     False
# 1  9.02  13.635        80        0.0     40     1    1      1  2011     False
# 2  9.02  13.635        80        0.0     32     2    1      1  2011     False
# 3  9.84  14.395        75        0.0     13     3    1      1  2011     False
# 4  9.84  14.395        75        0.0      1     4    1      1  2011     False
#
#    season_3  season_4  holiday_1  workingday_1  weather_2  weather_3  \
# 0     False     False      False         False      False      False
# 1     False     False      False         False      False      False
# 2     False     False      False         False      False      False
# 3     False     False      False         False      False      False
# 4     False     False      False         False      False      False
#
#    weather_4  transform_count
# 0      False         2.833213
# ...

# %%
from sklearn.model_selection import train_test_split

X = df_encoded.drop(columns=['count','transform_count'])
Y = df_encoded['transform_count']

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=42)

print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", y_train.shape)
print("X_test shape:", y_test.shape)
# Out:
# X_train shape: (6421, 16)
# X_test shape: (2753, 16)
# y_train shape: (6421,)
# X_test shape: (2753,)

# %%
# !pip install xgboost
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import xgboost as xgb
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    'learning_rate': [0.01,0.1,0.2],
    'n_estimatores': [100,200,300],
    'max_depth': [3,4,5],
}
xgb_reg = xgb.XGBRegressor()
grid_search = GridSearchCV(estimator = xgb_reg, param_grid=param_grid, scoring='neg_mean_squared_error', cv=5)
grid_search.fit(X_train, y_train)
best_params = grid_search.best_params_
best_estimator = grid_search.best_estimator_
print("Best_estimator:", best_estimator)
final_xgb_model = xgb.XGBRegressor(**best_params)
final_xgb_model.fit(X_train, y_train)
# Out:
# C:\Users\mdzai\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\core.py:158: UserWarning: [01:11:46] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "n_estimatores" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\mdzai\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\core.py:158: UserWarning: [01:11:46] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "n_estimatores" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\mdzai\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\core.py:158: UserWarning: [01:11:46] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# ...

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
y_pred = final_xgb_model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test,y_pred)
r2 = r2_score(y_test, y_pred)
print("MAE:", mae)
print("MSE:", mse)
print("R2:", r2)
# Out:
# MAE: 0.21592435132185583
# MSE: 0.09579015525807694
# R2: 0.9530072820012864
